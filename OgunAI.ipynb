# %%
# Ogun Prototype Starter
name = input("Who enters this space? ")
print(f"Ogun acknowledges your presence, {name}. All systems are watching.")
# Out:
# Who enters this space? Ogunkemi
# Ogun acknowledges your presence, Ogunkemi. All systems are watching.
